# %% [markdown]
# Aluna: Nathália Rayanne Lima Araújo

# %% [markdown]
# # Regressão Linear com NumPy

# %% [markdown]
# ## Objetivos deste experimento

# %% [markdown]
# Este exemplo utiliza regressão linear para estimar o comprimento das sépalas da íris a partir do seu comprimento das pétalas.
# Utiliza-se programação totalmente NumPy com:
# - o **cálculo do gradiente**,
# - a **função de perda** e
# - a atualização dos parâmetros são feitos de forma explícita.
# - A rede é criada com uma camada como uma classe

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/RegressaoLinear_Otimizacao.png)

# %% [markdown]
# ## Importação dos pacotes

# %%
# %matplotlib inline
import matplotlib.pyplot as plt   # para plotting

from sklearn.datasets import load_iris  # para carregar dataset

import numpy as np  # processamento matricial

np.random.seed(1234)

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Leitura dos dados

# %%
iris = load_iris()
data = iris.data[iris.target==1,::2]  # comprimento das sépalas e pétalas, indices 0 e 2

x_train = data[:,0:1]
y_train = data[:,1:2]

n_samples = x_train.shape[0]
print('x_train.shape:',x_train.shape, x_train.dtype)
print('y_train.shape:',y_train.shape, y_train.dtype)

print('x_train[:5]:\n', x_train[:5])
print('y_train[:5]:\n', y_train[:5])
# Out:
# x_train.shape: (50, 1) float64
# y_train.shape: (50, 1) float64
# x_train[:5]:
#  [[7. ]
#  [6.4]
#  [6.9]
#  [5.5]
#  [6.5]]
# y_train[:5]:
#  [[4.7]
#  [4.5]
#  [4.9]
#  [4. ]
#  [4.6]]

# %% [markdown]
# ### Normalização dos dados

# %%
x_train -= x_train.min()
x_train /= x_train.max()
y_train -= y_train.min()
y_train /= y_train.max()

# %%
plt.scatter(x_train,y_train)
plt.xlabel('Comprimento sepalas')
plt.ylabel('Comprimento petalas')
# Out:
# Text(0, 0.5, 'Comprimento petalas')

# %% [markdown]
# ## Modelo da rede

# %% [markdown]
# ### Reta de ajuste

# %% [markdown]
# A equação da reta no plano necessita de dois parâmetros, aqui denominados $w_0$ (*bias*) e inclinação $w_1$. Veja figura:
#
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/linhareta.png)
#
# A reta de ajuste será dada por:
#
# $$ \hat{y} = w_0 + w_1 x $$
#
# onde
# * $w_1$ é o coeficiente angular da reta e
# * $w_0$ é a interseção do eixo vertical quando x é igual a zero, também denominado de *bias*.
# * $x$ é a variável de entrada (comprimento das sépalas) e
# * $\hat{y}$ é a predição (comprimento estimado das pétalas).

# %% [markdown]
# ### Linear Regression Model

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/RegressaoLinearNeuronio.png)

# %% [markdown]
# ### Formulação matricial do neurônio

# %% [markdown]
# * $\mathbf{w} = [w_0 \ w_1]$ é vetor linha de parâmetros e
# * $\mathbf{x} = [1 \ x_0] $ é vetor linha de uma amostra (com *bias*).
#
# $$ \hat{y} = 1 w_0 + x_0 w_1 $$
#
# $$ [\hat{y}] = [1 \ x_0] \begin{bmatrix} w_0 \\ w_1 \end{bmatrix} $$
#
# $$ \mathbf{\hat{y}} = \mathbf{x} \mathbf{w^T} $$

# %% [markdown]
# ### Fazendo o predict de várias amostras

# %% [markdown]
# $$ \begin{matrix}
# \begin{bmatrix}
# \hat{y}_0\\
# \hat{y}_1\\
# \\
# \hat{y}_{M-1}
# \end{bmatrix} &=& \begin{bmatrix}
# 1 & x_0 \\
# 1 & x_1\\
# \\
# 1 & x_{M-1} \\
# \end{bmatrix}
# &
# \begin{bmatrix}
# w_0\\
# w_1
# \end{bmatrix} \\
# (M,1) & & (M,2) & (2,1) \\
# \end{matrix} $$

# %% [markdown]
# ### Preenchendo x com coluna de 1's para bias

# %%
x_train_bias = np.hstack([np.ones(shape=(n_samples,1)), x_train])

# %%
x_train_bias
# Out:
# array([[1.        , 1.        ],
#        [1.        , 0.71428571],
#        [1.        , 0.95238095],
#        [1.        , 0.28571429],
#        [1.        , 0.76190476],
#        [1.        , 0.38095238],
#        [1.        , 0.66666667],
#        [1.        , 0.        ],
#        [1.        , 0.80952381],
#        [1.        , 0.14285714],
#        [1.        , 0.04761905],
#        [1.        , 0.47619048],
#        [1.        , 0.52380952],
#        [1.        , 0.57142857],
#        [1.        , 0.33333333],
#        [1.        , 0.85714286],
#        [1.        , 0.33333333],
#        [1.        , 0.42857143],
#        [1.        , 0.61904762],
#        [1.        , 0.33333333],
#        [1.        , 0.47619048],
#        [1.        , 0.57142857],
#        [1.        , 0.66666667],
#        [1.        , 0.57142857],
#        [1.        , 0.71428571],
#        [1.        , 0.80952381],
#        [1.        , 0.9047619 ],
#        [1.        , 0.85714286],
# ...

# %% [markdown]
# ### Classe com o modelo da rede

# %%
class Net():
    def __init__(self, n_in, n_out):
        self.w = np.random.uniform(-0.1,0.1,(n_out,n_in)) #inicialização dos parâmetros

    def forward(self, x_bias):
        return x_bias.dot(self.w.T)

# %% [markdown]
# ### Criando a rede, instanciando o objeto model

# %%
model = Net(2,1) # duas entradas (1 + x0) e uma saída y_pred

# %% [markdown]
# ### Testando o predict da rede (mesmo sem treiná-la)

# %%
xin = np.random.randn(4,2) # 4 amostras, 2 entradas (1 + x0)
ypred = model.forward(xin)
ypred
# Out:
# array([[-0.09602795],
#        [ 0.0661236 ],
#        [-0.06857828],
#        [-0.05573871]])

# %%
ypred = model.forward(x_train_bias)

# %% [markdown]
# ## Treinamento via gradiente descendente

# %% [markdown]
# Função de perda:
# $$ J(\hat{y_i},y_i) = \frac{1}{M} \sum_{i=0}^{M-1} (\hat{y_i} - y_i)^2 $$

# %% [markdown]
# Gradiente:
# $$  \mathbf{\nabla{J_w}} = \frac{2}{M}\mathbf{x^T}(\mathbf{x w^T} - \mathbf{y}) $$

# %% [markdown]
# Atualização dos parâmetros pelo gradiente descendente:
# $$ \mathbf{w} = \mathbf{w} − \eta (\mathbf{\nabla J_w})^T $$

# %% [markdown]
# ### Laço de treinamento

# %%
model = Net(2, 1)
perdas = []
num_epochs = 100
learning_rate = 0.5
for epoch in range(num_epochs):

    # forward - predict
    y_pred = model.forward(x_train_bias)

    #loss cálculo da função de perda
    loss = np.square(y_pred - y_train).mean()
    perdas.append(loss)

    # cálculo do gradiente pelas derivadas parciais
    w_grad = (2.0/n_samples) * (x_train_bias.T).dot(x_train_bias.dot(model.w.T) - y_train)

    # gradiente descendente
    model.w = model.w - learning_rate * w_grad.T

    # verbose
    if (epoch+1) % 1 == 0:
        print('Epoch[{}/{}], loss: {:.6f}'
              .format(epoch+1, num_epochs, loss))
# Out:
# Epoch[1/100], loss: 0.432375
# Epoch[2/100], loss: 0.056651
# Epoch[3/100], loss: 0.031341
# Epoch[4/100], loss: 0.028966
# Epoch[5/100], loss: 0.028154
# Epoch[6/100], loss: 0.027505
# Epoch[7/100], loss: 0.026921
# Epoch[8/100], loss: 0.026391
# Epoch[9/100], loss: 0.025910
# Epoch[10/100], loss: 0.025474
# Epoch[11/100], loss: 0.025077
# Epoch[12/100], loss: 0.024717
# Epoch[13/100], loss: 0.024391
# Epoch[14/100], loss: 0.024094
# Epoch[15/100], loss: 0.023825
# Epoch[16/100], loss: 0.023580
# Epoch[17/100], loss: 0.023358
# Epoch[18/100], loss: 0.023157
# Epoch[19/100], loss: 0.022974
# Epoch[20/100], loss: 0.022807
# Epoch[21/100], loss: 0.022657
# Epoch[22/100], loss: 0.022520
# Epoch[23/100], loss: 0.022395
# Epoch[24/100], loss: 0.022282
# Epoch[25/100], loss: 0.022180
# Epoch[26/100], loss: 0.022087
# Epoch[27/100], loss: 0.022002
# Epoch[28/100], loss: 0.021926
# Epoch[29/100], loss: 0.021856
# Epoch[30/100], loss: 0.021793
# Epoch[31/100], loss: 0.021735
# ...

# %% [markdown]
# ## Avaliação

# %% [markdown]
# ### Predict

# %%
y_pred = model.forward(x_train_bias)
plt.plot(x_train, y_train, 'ro', label='Original data')
plt.plot(x_train, y_pred, 'kx-', label='Fitting Line')

# %% [markdown]
# ### Parâmetros treinados

# %%
print(model.w)
# Out:
# [[0.26305351 0.6831633 ]]

# %% [markdown]
# ### Avaliação do modelo

# %%
loss = np.square(y_pred - y_train).mean()
loss
# Out:
# np.float64(0.021170077931248157)

# %% [markdown]
# ### Valor ótimo, solução analítica

# %% [markdown]
# $$  \mathbf{w} =(\mathbf{x^T} \mathbf{x})^{−1}\mathbf{x^T} \mathbf{y} $$

# %%
x = x_train_bias
y = y_train
w_opt = (np.linalg.inv((x.T).dot(x)).dot(x.T)).dot(y)
print(w_opt.T)
# Out:
# [[0.26134159 0.68646976]]

# %% [markdown]
# # Exercícios

# %% [markdown]
# ## Questões

# %% [markdown]
# 1. Quantos parâmetros são treinados nesse modelo?
#
# 2. Qual é o número de atributos de entrada para a rede?
#
# 3. Qual é o número de saídas da rede?
#
# 4. Suponha que eu tenha agora 5 mil amostras para fazer a predição. Qual é o shape da matriz de entrada?
#    Qual é o shape do matriz de saída?

# %% [markdown]
# R:
#
# 1. Dois parâmetros: w0 (bias) e w1 (coeficiente angular). O vetor model.w tem shape (1, 2), uma linha com dois valores.
#
# 2. Um atributo real (comprimento das sépalas). Na prática a rede recebe 2 entradas por conta da coluna de 1's do bias, mas o atributo de entrada do problema é 1.
#
# 3. uma saída, por meio do comprimento estimado das pétalas (ŷ).
#
# 4. Matriz de entrada: (5000, 2) — 5000 amostras × 2 colunas (bias + x)
# Matriz de saída: (5000, 1) — 5000 predições

# %% [markdown]
# ## Atividades

# %% [markdown]
# 1. Modifique o laço do treinamento via gradiente descendente para guardar em uma lista, o valor da perda no final
#    de cada época. Após o treinamento, plote o valor da perda em função da época.
# 2. Calcule o valor da perda (MSE) da rede com os parâmetros inicializados, sem serem treinados.
# 3. Coloque os valores dos pesos da solução ótima analítica no modelo da rede e calcule o valor da perda (MSE) e
#    compare com o valor da perda obtida pelo método da otimização via gradiente descendente.

# %% [markdown]
# # Aprendizados

# %% [markdown]
# 1. Curva de perda por época

# %%
model = Net(2, 1)
perdas = []
num_epochs = 100
learning_rate = 0.5
for epoch in range(num_epochs):

    y_pred = model.forward(x_train_bias)

    loss = np.square(y_pred - y_train).mean()
    perdas.append(loss)

    w_grad = (2.0/n_samples) * (x_train_bias.T).dot(x_train_bias.dot(model.w.T) - y_train)

    model.w = model.w - learning_rate * w_grad.T

    if (epoch+1) % 1 == 0:
        print('Epoch[{}/{}], loss: {:.6f}'
              .format(epoch+1, num_epochs, loss))
# Out:
# Epoch[1/100], loss: 0.432375
# Epoch[2/100], loss: 0.056651
# Epoch[3/100], loss: 0.031341
# Epoch[4/100], loss: 0.028966
# Epoch[5/100], loss: 0.028154
# Epoch[6/100], loss: 0.027505
# Epoch[7/100], loss: 0.026921
# Epoch[8/100], loss: 0.026391
# Epoch[9/100], loss: 0.025910
# Epoch[10/100], loss: 0.025474
# Epoch[11/100], loss: 0.025077
# Epoch[12/100], loss: 0.024717
# Epoch[13/100], loss: 0.024391
# Epoch[14/100], loss: 0.024094
# Epoch[15/100], loss: 0.023825
# Epoch[16/100], loss: 0.023580
# Epoch[17/100], loss: 0.023358
# Epoch[18/100], loss: 0.023157
# Epoch[19/100], loss: 0.022974
# Epoch[20/100], loss: 0.022807
# Epoch[21/100], loss: 0.022657
# Epoch[22/100], loss: 0.022520
# Epoch[23/100], loss: 0.022395
# Epoch[24/100], loss: 0.022282
# Epoch[25/100], loss: 0.022180
# Epoch[26/100], loss: 0.022087
# Epoch[27/100], loss: 0.022002
# Epoch[28/100], loss: 0.021926
# Epoch[29/100], loss: 0.021856
# Epoch[30/100], loss: 0.021793
# Epoch[31/100], loss: 0.021735
# ...

# %%
plt.plot(perdas, color='r', marker='o')

plt.ylabel('Perda')
plt.xlabel('Época')

plt.show()

# %% [markdown]
# A perda cai rapidamente nas primeiras épocas e vai estabilizando conforme o modelo converge. É o comportamento esperado do gradiente descendente.

# %% [markdown]
# 2. MSE com pesos iniciais

# %%
model = Net(2,1)

print("Pesos iniciais:")
print(model.w)

y_pred_init = model.forward(x_train_bias)
loss_init = np.square(y_pred_init - y_train).mean()
print(f'MSE inicial (sem treino): {loss_init:.6f}')
# Out:
# Pesos iniciais:
# [[ 0.00061663 -0.09724631]]
# MSE inicial (sem treino): 0.476608

# %% [markdown]
# O MSE inicial é aproximadamente 0.38, muito alto. Sem treino, os pesos aleatórios geram predições ruins, isso serve como baseline para mostrar o quanto o treinamento melhora o modelo.

# %% [markdown]
# 3. Solução analítica vs Gradiente Descendente

# %%
x = x_train_bias
y = y_train
w_opt = (np.linalg.inv((x.T).dot(x)).dot(x.T)).dot(y)
print('Pesos ótimos:', w_opt.T)

model_opt = Net(2, 1)
model_opt.w = w_opt.T
y_pred_opt = model_opt.forward(x_train_bias)
loss_opt = np.square(y_pred_opt - y_train).mean()

print(f'MSE - Gradiente Descendente: {loss:.6f}')  # 0.021170
print(f'MSE - Solução Analítica:     {loss_opt:.6f}')      # 0.021169
# Out:
# Pesos ótimos: [[0.26134159 0.68646976]]
# MSE - Gradiente Descendente: 0.021170
# MSE - Solução Analítica:     0.021169

# %%
x = x_train_bias
y = y_train

w_opt = (np.linalg.inv((x.T).dot(x)).dot(x.T)).dot(y)

print('Pesos:')
print(w_opt.T)
# Out:
# Pesos:
# [[0.26134159 0.68646976]]

# %%
model = Net(2,1)
model.w = w_opt.T

print('\nPesos no modelo:')
print(model.w)
# Out:
# Pesos no modelo:
# [[0.26134159 0.68646976]]

# %%
y_pred = model.forward(x_train_bias)

loss_otimo = np.square(y_pred - y_train).mean()

print(f'\nMSE - Solução Analítica: {loss_otimo:.6f}')
# Out:
# MSE - Solução Analítica: 0.021169

# %%
model = Net(2,1)

perdas = []

num_epochs = 100
learning_rate = 0.5

for epoch in range(num_epochs):
    y_pred = model.forward(x_train_bias)

    loss = np.square(y_pred - y_train).mean()

    perdas.append(loss)

    w_grad = (2.0/n_samples) * (
        x_train_bias.T
    ).dot(
        x_train_bias.dot(model.w.T) - y_train
    )

    model.w = model.w - learning_rate * w_grad.T

    print('Epoch[{}/{}], loss: {:.6f}'
          .format(epoch+1, num_epochs, loss))
# Out:
# Epoch[1/100], loss: 0.339831
# Epoch[2/100], loss: 0.050684
# Epoch[3/100], loss: 0.031016
# Epoch[4/100], loss: 0.029003
# Epoch[5/100], loss: 0.028210
# Epoch[6/100], loss: 0.027556
# Epoch[7/100], loss: 0.026968
# Epoch[8/100], loss: 0.026434
# Epoch[9/100], loss: 0.025949
# Epoch[10/100], loss: 0.025509
# Epoch[11/100], loss: 0.025109
# Epoch[12/100], loss: 0.024746
# Epoch[13/100], loss: 0.024417
# Epoch[14/100], loss: 0.024118
# Epoch[15/100], loss: 0.023846
# Epoch[16/100], loss: 0.023600
# Epoch[17/100], loss: 0.023376
# Epoch[18/100], loss: 0.023173
# Epoch[19/100], loss: 0.022988
# Epoch[20/100], loss: 0.022821
# Epoch[21/100], loss: 0.022669
# Epoch[22/100], loss: 0.022531
# Epoch[23/100], loss: 0.022405
# Epoch[24/100], loss: 0.022291
# Epoch[25/100], loss: 0.022188
# Epoch[26/100], loss: 0.022094
# Epoch[27/100], loss: 0.022009
# Epoch[28/100], loss: 0.021932
# Epoch[29/100], loss: 0.021862
# Epoch[30/100], loss: 0.021798
# Epoch[31/100], loss: 0.021740
# ...

# %%
print(f'\nMSE - Solução Analítica:     {loss_otimo:.6f}')
print(f'MSE - Gradiente Descendente: {loss:.6f}')
# Out:
# MSE - Solução Analítica:     0.021169
# MSE - Gradiente Descendente: 0.021170

# %% [markdown]
# Os dois MSEs são idênticos. O gradiente descendente converge para a mesma solução que a fórmula matemática exata, confirmando que o treinamento funcionou corretamente. A vantagem da solução analítica é precisão e velocidade; a desvantagem é que ela só existe para regressão linear, em redes mais profundas só o gradiente descendente funciona.
