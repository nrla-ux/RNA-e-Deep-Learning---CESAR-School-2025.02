# %%
Aluna: Nathália Rayanne Lima Araújo

# %% [markdown]
# # Datasets e DataLoaders no Pytorch

# %% [markdown]
# Demonstração do funcionamento dos Datasets e Dataloaders no Pytorch

# %% [markdown]
# ### Objetivo

# %% [markdown]
# O objetivo deste notebook é demonstrar as três formas de carregar e usar dados no PyTorch:
#
# * torch.utils.data.TensorDataset
# * torch.utils.data.Dataset
# * torch.utils.data.DataLoader
#
# Neste notebook usaremos o dataset de Flores Íris, já visto anteriormente

# %%
import numpy as np
import torch
from torch.utils.data import TensorDataset

from torchvision import transforms

from sklearn.datasets import load_iris

# %% [markdown]
# # Datasets

# %% [markdown]
# No Pytorch, datasets são objetos utilizados para armazenar, indexar, transformar e retornar elementos de um conjunto de dados.
#
# Existem duas formas de se criar um dataset em PyTorch:
#
# * Transformar os dados de entrada em tensores torch e criar o dataset com torch.utils.data.TensorDataset¶
# * Criar uma classe filha de torch.utils.data.Dataset

# %% [markdown]
# ## Criando um Dataset com `torch.utils.data.TensorDataset`

# %% [markdown]
# Se os dados e as classes forem disponibilizados em arrays do numpy ou tensores do próprio PyTorch é possível criar um dataset utilizando [torch.utils.data.TensorDataset](http://pytorch.org/docs/master/data.html#torch.utils.data.TensorDataset):

# %% [markdown]
# ### Dados anotados: x_data (comprimento das sépalas) e target (comprimento das pétalas)

# %%
iris = load_iris()
data = iris.data[iris.target==1,::2]  # comprimento das sépalas e pétalas, indices 0 e 2

x_data = data[:,0:1]
target = data[:,1:2]

print('dimensões de x_data:', x_data.shape)
print('dimensões de target:', target.shape)
# Out:
# dimensões de x_data: (50, 1)
# dimensões de target: (50, 1)

# %% [markdown]
# ### Passo 1: transformar o array numpy em tensores torch

# %%
x_data = torch.FloatTensor(x_data)
target = torch.FloatTensor(target)

# %% [markdown]
# ### Passo 2: usar `TensorDataset` para criar o dataset com os tensores

# %%
dataset = TensorDataset(x_data, target)
len(dataset)
# Out:
# 50

# %% [markdown]
# O dataset pode ser indexado como uma lista e cada elemento retorna uma tupla:
# - dado de entrada e
# - dado de saída.

# %%
i = 10
(x, y) = dataset[i]

print('sépala:', x)
print('pétala:', y)
# Out:
# sépala: tensor([5.])
# pétala: tensor([3.5000])

# %% [markdown]
# ## Criando um Dataset com `torch.utils.data.Dataset`

# %% [markdown]
# É possível criar uma nova classe personalizada representando um dataset. Esta classe deve herdar de [torch.utils.data.Dataset](http://pytorch.org/docs/master/data.html#torch.utils.data.Dataset) para tratar casos mais complexos e especiais.

# %% [markdown]
# ### Estrutura do Dataset

# %% [markdown]
# Sempre que se herda de `Dataset` é preciso implementar os métodos:
# - `__len__`: para retornar o tamanho do dataset, e
# - `__getitem__`: para retornar um elemento de um índice dado.
#
# O método `__len__` é chamado quando usamos a chamada `len(dataset)` do Python e `__getitem__` é chamado quando fazemos a indexação `dataset[i]`.
#
# É possível inicializar variáveis da classe no construtor (`__init__`) do dataset.

# %%
from torch.utils.data import Dataset

class IrisDataset(Dataset):
    def __init__(self, x_data, target):
        super(IrisDataset, self).__init__()

        self.data = x_data
        self.target = target

    def __len__(self):
        return self.data.shape[0]

    def __getitem__(self, index):

        sepala = self.data[index]
        petala = self.target[index]

        return (sepala, petala)

# %% [markdown]
# Nossa classe está pronta, podemos criar um objeto dela.

# %% [markdown]
# ### Criando e testando um objeto da nossa classe

# %% [markdown]
# Para exemplificar o uso de classes de transformação os dados foram novamente gerados como array numpy.

# %%
x = data[:,0:1]
y = data[:,1:2]

dataset = IrisDataset(x, y)

# %% [markdown]
# Nosso método `__len__` deve retornar o tamanho da primeira dimensão dos dados.
#
# Podemos verificar se o método está correto chamando o `len()` do Python:

# %%
print(len(dataset))
# Out:
# 50

# %% [markdown]
# Nosso método `__getitem__()` deve retornar uma tupla na i-ésima posição no dataset, no nosso caso `data[i]` e `target[i]`:

# %%
i = 1
print(dataset[i])
# Out:
# (array([6.4]), array([4.5]))

# %%
data, target = dataset[30]

print('sépala:', data)
print('pétala:', target)
# Out:
# sépala: [5.5]
# pétala: [3.8]

# %% [markdown]
# ### Conclusão

# %% [markdown]
# O caso apresentado neste tópico é muito simples, apresentando os conceitos básicos da estrutura que o Pytorch utiliza para representar datasets. A classe torch.utils.data.Dataset é usada para casos complexos em que é preciso, por exemplo, carregar o dataset de arquivos e quando o gerenciamento dos dados não é tão trivial ou quando queremos aplicar uma transformação ao dado.

# %% [markdown]
# # DataLoaders

# %% [markdown]
# Um DataLoader ([torch.utils.data.DataLoader](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader)) combina um Dataset e um Sampler (divide os dados em batches).
#
# O DataLoader permite que os dados possam ser processados na forma de "mini-batches". A cada nova chamada do objeto criado com o DataLoader, um novo conjunto de dados é retornado. O DataLoader é a ferramenta do PyTorch para implementar o treinamento do gradiente descendente por "mini-batches". O treinamento por mini-batches possui duas grandes vantagens:
# - Implementa o gradiente descendente estocástico via mini-batch, que acelera o treinamento;
# - Permite que os dados do mini-batch a serem otimizados caibam na memória (normalmente da GPU).

# %% [markdown]
# ## Criando um DataLoader

# %% [markdown]
# Vamos utilizar o dataset já criado anteriormente para ser a fonte de dados do nosso DataLoader.

# %%
print('tamanho do dataset: ', len(dataset))
print('amostra 12:', dataset[12])
# Out:
# tamanho do dataset:  50
# amostra 12: (array([6.]), array([4.]))

# %% [markdown]
# Agora podemos criar o DataLoader com o dataset

# %%
from torch.utils.data import DataLoader

data_loader = DataLoader(dataset,
                         batch_size=10, # tamanho do mini-batch de dados
                         shuffle=False) # se for True, embaralha os dados no inicio de cada iteração

# %% [markdown]
# ## Iterando sobre o DataLoader

# %% [markdown]
# Podemos iterar sobre o DataLoader utilizando um `for`

# %%
batch_n = 0
n_samples = 0
for data in data_loader:
    print('batch ', batch_n)
    batch_n += 1
    n_samples += len(data[0])

print('tamanho do DataLoader', len(data_loader))
print('tamanho do dataset', n_samples)
# Out:
# batch  0
# batch  1
# batch  2
# batch  3
# batch  4
# tamanho do DataLoader 5
# tamanho do dataset 50

# %% [markdown]
# O tamanho do DataLoader é 5, pois temos batches de tamanho 10 dados no dataloader.
#
# Agora podemos utilizar os dados do DataLoader:

# %%
batch_n = 0

for data in data_loader:
    # separa a tupla em petalas e sépalas
    data_batch, targets_batch = data

    print('dimensão do batch de sépalas {}:   {}'.format(batch_n, data_batch.size()))
    print('dimensão do batch de pétalas {}: {}\n'.format(batch_n, targets_batch.size()))
    batch_n += 1
# Out:
# dimensão do batch de sépalas 0:   torch.Size([10, 1])
# dimensão do batch de pétalas 0: torch.Size([10, 1])
#
# dimensão do batch de sépalas 1:   torch.Size([10, 1])
# dimensão do batch de pétalas 1: torch.Size([10, 1])
#
# dimensão do batch de sépalas 2:   torch.Size([10, 1])
# dimensão do batch de pétalas 2: torch.Size([10, 1])
#
# dimensão do batch de sépalas 3:   torch.Size([10, 1])
# dimensão do batch de pétalas 3: torch.Size([10, 1])
#
# dimensão do batch de sépalas 4:   torch.Size([10, 1])
# dimensão do batch de pétalas 4: torch.Size([10, 1])

# %% [markdown]
# É possível ver que os batches tem mesmo 10 dados (5 matrizes 10x1 para as sépalas e 5 matrizes 10x1 para as pétalas)

# %% [markdown]
# No exemplo abaixo é possível ver que, com shuffle igual o False, os dados de cada mini-batch são sempre os mesmos. Cada cor contém os dados de um mini-batch:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data_loader = DataLoader(dataset,
                         batch_size=10, # tamanho do mini-batch de dados
                         shuffle=False) # se for True, embaralha os dados no inicio de cada iteração

# %%
color = ["b","g","r","c","m"]
mark = ['+', '.', '^', 'o', 'x']
fig = plt.figure(figsize=(16,5))
ax1 = fig.add_subplot(1,2,1)
ax1.set_xlabel('Comprimento sepalas')
ax1.set_ylabel('Comprimento petalas')
ax1.set_title('Primeira iteração')

for i,data in enumerate(data_loader):
    # separa a tupla em petalas e sépalas
    data_batch, targets_batch = data

    ax1.scatter(data_batch, targets_batch, c=color[i], marker=mark[i])

ax2 = fig.add_subplot(1,2,2)
ax2.set_xlabel('Comprimento normalizado sepalas')
ax2.set_ylabel('Comprimento normalizado petalas')
ax2.set_title('Segunda iteração')

for i,data in enumerate(data_loader):
    # separa a tupla em petalas e sépalas
    data_batch, targets_batch = data

    ax2.scatter(data_batch, targets_batch, c=color[i], marker=mark[i])

# %% [markdown]
# Com shuffle igual a True, os dados do mini-batch sempre mudam a cada iteração:

# %%
data_loader = DataLoader(dataset,
                         batch_size=10, # tamanho do mini-batch de dados
                         shuffle=True)  # se for True, embaralha os dados no inicio de cada iteração

# %%
color = ["b","g","r","c","m"]
mark = ['+', '.', '^', 'o', 'x']
fig = plt.figure(figsize=(16,5))
ax1 = fig.add_subplot(1,2,1)
ax1.set_xlabel('Comprimento sepalas')
ax1.set_ylabel('Comprimento petalas')
ax1.set_title('Primeira iteração')

for i,data in enumerate(data_loader):
    # separa a tupla em petalas e sépalas
    data_batch, targets_batch = data

    ax1.scatter(data_batch, targets_batch, c=color[i], marker=mark[i])

ax2 = fig.add_subplot(1,2,2)
ax2.set_xlabel('Comprimento normalizado sepalas')
ax2.set_ylabel('Comprimento normalizado petalas')
ax2.set_title('Segunda iteração')

for i,data in enumerate(data_loader):
    # separa a tupla em petalas e sépalas
    data_batch, targets_batch = data

    ax2.scatter(data_batch, targets_batch, c=color[i], marker=mark[i])

# %% [markdown]
# ## Exercício

# %% [markdown]
# Defina seu próprio DataLoader na segunda célula abaixo. Faça com que cada batch tenha 5 elementos cada. Utilize o dataset já criado anteriormente.
#
# Em seguida imprima o tamanho do Dataloader e tamanho do Dataset

# %%
# -- Defina aqui seu DataLoader com batches de 5 elementos cada ---
data_loader = None

# # -- tamanho do Dataloader e tamanho do Dataset


print('tamanho do DataLoader', )
print('tamanho do dataset', )
# Out:
# tamanho do DataLoader
# tamanho do dataset

# %% [markdown]
# - A ordem dos elementos se altera entre execuções da célula acima?
# - Tente colocar o parametro `shuffle` do DataLoader como `True` e obeseve o resultado do exercício, rodando várias vezes.

# %%
from torch.utils.data import DataLoader

data_loader = DataLoader(dataset,
                         batch_size=5,
                         shuffle=False)

print('tamanho do DataLoader:', len(data_loader))
print('tamanho do Dataset:   ', len(dataset))
# Out:
# tamanho do DataLoader: 10
# tamanho do Dataset:    50

# %%
data_loader_shuffle = DataLoader(dataset,
                                 batch_size=5,
                                 shuffle=True)

for i, (x_batch, y_batch) in enumerate(data_loader_shuffle):
    print(f"Batch {i+1}: sépalas = {x_batch.squeeze().tolist()}")
# Out:
# Batch 1: sépalas = [6.2, 5.6, 5.6, 6.6, 5.4]
# Batch 2: sépalas = [5.1, 6.1, 6.4, 6.7, 6.4]
# Batch 3: sépalas = [5.7, 5.0, 5.5, 5.7, 6.0]
# Batch 4: sépalas = [5.6, 7.0, 5.8, 5.6, 5.5]
# Batch 5: sépalas = [6.9, 5.5, 6.0, 4.9, 6.6]
# Batch 6: sépalas = [6.2, 5.5, 6.8, 5.7, 5.8]
# Batch 7: sépalas = [5.6, 5.7, 6.3, 6.7, 6.5]
# Batch 8: sépalas = [6.0, 5.9, 5.9, 5.5, 6.0]
# Batch 9: sépalas = [5.7, 6.3, 6.1, 6.1, 6.3]
# Batch 10: sépalas = [6.1, 5.0, 6.7, 5.8, 5.2]

# %% [markdown]
# # Aprendizados

# %% [markdown]
# Com base nesses resultados, podemos aprender que a forma como os dados são organizados e entregues ao modelo influencia diretamente a qualidade do treinamento da rede neural.
#
# Quando utilizamos *shuffle=False*, os dados são apresentados sempre na mesma sequência, o que pode fazer o modelo memorizar padrões relacionados à ordem dos exemplos em vez de aprender as características reais dos dados. Mas com "shuffle=True", os dados são embaralhados a cada época, permitindo que o modelo veja combinações diferentes de exemplos durante o treinamento. Isso torna o aprendizado mais robusto e reduz o risco de *overfitting*.
#
# Outro aprendizado é sobre o funcionamento do *DataLoader*. Ele divide o conjunto de dados em mini-batches, facilitando o processamento e economizando memória. O cálculo do tamanho do DataLoader também mostra quantos batches serão processados em cada época do treinamento:
#
# len(data_loader)=⌈len(dataset)/batch_size⌉
#
# len(data_loader)=⌈len(dataset)/batch_size⌉
#
# No exemplo apresentado, com 50 amostras e batch_size = 5, o treinamento ocorre em 10 batches. Isso ajuda a entender como os dados são distribuídos ao longo do treinamento e como o modelo aprende de maneira progressiva e eficiente.
